# %% [markdown]
# # 🧠 Assignment 1 – Basic Probability
#     --By ( Group - 5, Batch - A):
#         CB.SC.U4AIE23006 Ansh Raj Rath
#         CB.SC.U4AIE23002 Abiruth S.
#         CB.SC.U4AIE23012 Aditya Krishna Samant
#         CB.SC.U4AIE23023 Dinesh Karthikeyan
#
#
# ---
#
# ## 📋 Questions
#
# 1. **Give some examples of a random experiment.**
#
# <br>
#
# 2. **What is an _event_ associated with a random experiment?**
#    Give some examples.
#
# <br>
#
# 3. **What is a _simple event_?**
#    Give some examples.
#
# <br>
#
# 4. **What is a _certain event_?**
#    Give some examples.
#
# <br>
#
# 5. **What is a _compound event_?**
#    Give some examples.
#
# <br>
#
# 6. **What is an _impossible event_?**
#    Give some examples.
#
# <br>
#
# 7. **When are two events called _identical events_?**
#    Give some examples.
#
# <br>
#
# 8. **When are two events called _mutually exclusive_?**
#    Give some examples.
#
# <br>
#
# 9. **Definition of Probability:**
#    - Classical definition
#    - Frequency definition
#
# <br>
#
# 10. **Definition of _Conditional Probability_**
#
# <br>
#
# 11. **Write down _Bayes’ Theorem_.**
#
# <br>
#
# 12. **General Addition Rule in Probability:**
#     \( P(A + B + C) = ? \)
#
# <br>
#
# 13. **General Multiplication Rule in Probability:**
#     \( P(ABC) = ? \)
#
# <br>
#
# 14. **A coin is tossed 3 times. Find the probability of:**
#     - (a) 2 heads
#     - (b) 2 consecutive heads
#
# <br>
#
# 15. **Two dice are thrown. Find the probability that the sum is ≥ 10.**
#
# <br>
#
# 16. **A die is thrown _k_ times. Find the probability of getting six at least once.**
#
# <br>
#
# 17. **A card is drawn at random from each of two shuffled packs.**
#     Find the probability that **at least one is the Queen of Spades.**
#
# <br>
#
# 18. **Urn Problem:** An urn contains 2 white and 3 black balls.
#     Balls are drawn in order. Find the probability of the order: `WBBWB`.
#
# <br>
#
# 19. **Generalized Urn Problem:**
#     An urn contains \( N = N_1 + N_2 \) balls.
#     - (a) What is the probability of drawing a white ball?
#     - (b) What is the probability of drawing exactly _i_ white balls out of _n_ draws?
#
# <br>
#
# 20. **What is the probability that a bridge hand of 13 cards contains one ace?**
#
# <br>
#
# 21. **Probability a bridge hand contains:**
#     - 5 Spades
#     - 4 Hearts
#     - 3 Diamonds
#     - 1 Club
#
# <br>
#
# 22. **A die is rolled. If result is an even number or a multiple of 3, I win.**
#     Let \( A = \text{even face} \), \( B = \text{multiple of 3} \).
#     Find:
#     - \( P(B | A) \)
#     - \( P(A | B) \)
#
# <br>
#
# 23. **Two cards are drawn successively (without replacement).**
#     If first is a Spade, find the probability second is also a Spade.
#
# <br>
#
# 24. **Repeat previous: Find probability both cards are Spades.**
#
# <br>
#
# 25. **In an exam:**
#     - 30% failed in Math
#     - 15% failed in Chemistry
#     - 10% failed in both
#     If a student failed in Chemistry, find:
#     - (a) Probability they passed in Math
#     - (b) Probability they failed in both
#
# <br>
#
# 26. **Three identical urns:**
#     - Urn 1: 2W, 3B
#     - Urn 2: 3W, 5B
#     - Urn 3: 5W, 2B
#     An urn is picked at random. A ball drawn is white.
#     What is the probability that **Urn 2 was chosen**?
#
# <br>
#
# 27. **Tuberculosis Detection:**
#
# - $$ P(\text{detect TB} \mid \text{has TB}) = 1 - b $$
# - $$ P(\text{diagnose TB} \mid \text{healthy}) = a $$
# - Proportion of TB patients: \( c \)
#
# What is:
#
# $$ P(\text{healthy} \mid \text{diagnosed TB}) \, = \, ? $$
#
# ---
